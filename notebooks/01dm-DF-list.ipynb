# %% [markdown]
# Data Frame

# %%
import pandas as pd

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],    
    "gender": ["F", "M", "M"]
}
data
# Out:
# {'name': ['Alice', 'Bob', 'Charlie'],
#  'age': [25, 30, 35],
#  'gender': ['F', 'M', 'M']}

# %%
df = pd.DataFrame(data)
df
# Out:
#       name  age gender
# 0    Alice   25      F
# 1      Bob   30      M
# 2  Charlie   35      M

# %%
datalist = [100,70,80]
datalist
# Out:
# [100, 70, 80]

# %%
datalist[0] = datalist[0]/2

datalist
# Out:
# [50.0, 70, 80]

# %%
mytuple = tuple(datalist)
mytuple
# Out:
# (50.0, 70, 80)

# %%
mytuple[0] = mytuple[0]/2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 mytuple[0] = mytuple[0]/2
#
# TypeError: 'tuple' object does not support item assignment
