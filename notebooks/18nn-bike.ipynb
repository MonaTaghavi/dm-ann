# %% [markdown]
# Bike NN Model (Regression)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.neural_network import MLPRegressor

# %%
df = pd.read_csv("../data/bike_cleaned.csv")
df.head()
# Out:
#    Unnamed: 0  holiday  workingday   weather      temp     atemp  humidity  \
# 0           0        0           0 -0.660915 -1.339086 -1.103724  0.984434
# 1           1        0           0 -0.660915 -1.444375 -1.193741  0.932031
# 2           2        0           0 -0.660915 -1.444375 -1.193741  0.932031
# 3           3        0           0 -0.660915 -1.339086 -1.103724  0.670013
# 4           4        0           0 -0.660915 -1.339086 -1.103724  0.670013
#
#    windspeed  casual  registered  ...  season_sin    season_cos  month_sin  \
# 0  -1.652104       3          13  ...         1.0  6.123234e-17        0.5
# 1  -1.652104       8          32  ...         1.0  6.123234e-17        0.5
# 2  -1.652104       5          27  ...         1.0  6.123234e-17        0.5
# 3  -1.652104       3          10  ...         1.0  6.123234e-17        0.5
# 4  -1.652104       0           1  ...         1.0  6.123234e-17        0.5
#
# ...

# %% [markdown]
# Test/Train Split

# %%
x = df.drop(columns=['count', 'casual', 'registered', 'Unnamed: 0'])
y = df['count']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train
# Out:
#       holiday  workingday   weather      temp     atemp  humidity  windspeed  \
# 6567        0           0  0.923587 -0.286194 -0.206515  1.351259  -0.442790
# 2709        0           1 -0.660915  1.503722  1.587903 -0.011234   0.632356
# 9290        0           1 -0.660915  0.556119  0.870136 -1.164113   0.632356
# 4742        0           1  2.508089  0.240252  0.242385 -0.116041   0.364020
# 2484        0           1 -0.660915  0.766698  0.870136 -0.797288  -0.173553
# ...       ...         ...       ...       ...       ...       ...        ...
# 5734        0           1 -0.660915 -0.496772 -0.385957 -0.640077  -0.173553
# 5191        0           1  0.923587 -0.707351 -0.834858 -0.011234   0.901592
# 5390        0           1 -0.660915 -1.549664 -1.462608 -0.587673  -0.845294
# 860         0           1 -0.660915 -1.444375 -1.552625  0.355591   0.364020
# 7270        0           1 -0.660915  0.029673  0.062351 -0.587673   2.110906
#
# ...

# %%
y_train
# Out:
# 6567    503
# 2709    245
# 9290    289
# 4742    153
# 2484    135
#        ...
# 5734     18
# 5191    280
# 5390      5
# 860       5
# 7270    154
# Name: count, Length: 8527, dtype: int64

# %%
#Scaling y_train
target_scaler = StandardScaler()
y_train_scaled = target_scaler.fit_transform(y_train.values.reshape(-1, 1))

# %%
#Load MLPRegressor
model = MLPRegressor(hidden_layer_sizes=(100, 50), activation='relu', solver='adam', 
                            max_iter=1000, random_state=42, verbose=True, early_stopping=True, 
                            n_iter_no_change=100)
#fit the model
model.fit(x_train, y_train_scaled)
# Out:
# c:\Users\monat\anaconda3\envs\ai\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:1771: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Iteration 1, loss = 0.32643316
# Validation score: 0.464519
# Iteration 2, loss = 0.24272152
# Validation score: 0.539504
# Iteration 3, loss = 0.21167186
# Validation score: 0.590997
# Iteration 4, loss = 0.18965989
# Validation score: 0.624835
# Iteration 5, loss = 0.16968505
# Validation score: 0.669188
# Iteration 6, loss = 0.15023639
# Validation score: 0.700274
# Iteration 7, loss = 0.13414343
# Validation score: 0.730175
# Iteration 8, loss = 0.11997440
# Validation score: 0.747006
# Iteration 9, loss = 0.11062833
# Validation score: 0.770894
# Iteration 10, loss = 0.10234250
# Validation score: 0.781513
# Iteration 11, loss = 0.09544862
# Validation score: 0.789621
# ...
