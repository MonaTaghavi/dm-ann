# %% [markdown]
# # NN Regression - Diabetes

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
import plotly.express as px

# %%
data = load_diabetes()
print(data.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
df = pd.DataFrame(data.data, columns=data.feature_names)

# %%
df.head()
# Out:
#         age       sex       bmi  ...        s4        s5        s6
# 0  0.038076  0.050680  0.061696  ... -0.002592  0.019907 -0.017646
# 1 -0.001882 -0.044642 -0.051474  ... -0.039493 -0.068332 -0.092204
# 2  0.085299  0.050680  0.044451  ... -0.002592  0.002861 -0.025930
# 3 -0.089063 -0.044642 -0.011595  ...  0.034309  0.022688 -0.009362
# 4  0.005383 -0.044642 -0.036385  ... -0.002592 -0.031988 -0.046641
#
# [5 rows x 10 columns]

# %%
df['target'] = data.target
df.head()
# Out:
#         age       sex       bmi        bp  ...        s4        s5        s6  target
# 0  0.038076  0.050680  0.061696  0.021872  ... -0.002592  0.019907 -0.017646   151.0
# 1 -0.001882 -0.044642 -0.051474 -0.026328  ... -0.039493 -0.068332 -0.092204    75.0
# 2  0.085299  0.050680  0.044451 -0.005670  ... -0.002592  0.002861 -0.025930   141.0
# 3 -0.089063 -0.044642 -0.011595 -0.036656  ...  0.034309  0.022688 -0.009362   206.0
# 4  0.005383 -0.044642 -0.036385  0.021872  ... -0.002592 -0.031988 -0.046641   135.0
#
# [5 rows x 11 columns]

# %%
df.dtypes
# Out:
# age       float64
# sex       float64
# bmi       float64
# bp        float64
# s1        float64
# s2        float64
# s3        float64
# s4        float64
# s5        float64
# s6        float64
# target    float64
# dtype: object

# %%
df.describe()
# Out:
#                 age           sex  ...            s6      target
# count  4.420000e+02  4.420000e+02  ...  4.420000e+02  442.000000
# mean  -2.511817e-19  1.230790e-17  ...  1.130318e-17  152.133484
# std    4.761905e-02  4.761905e-02  ...  4.761905e-02   77.093005
# min   -1.072256e-01 -4.464164e-02  ... -1.377672e-01   25.000000
# 25%   -3.729927e-02 -4.464164e-02  ... -3.317903e-02   87.000000
# 50%    5.383060e-03 -4.464164e-02  ... -1.077698e-03  140.500000
# 75%    3.807591e-02  5.068012e-02  ...  2.791705e-02  211.500000
# max    1.107267e-01  5.068012e-02  ...  1.356118e-01  346.000000
#
# [8 rows x 11 columns]

# %%
df.sex.unique()
# Out:
# array([ 0.05068012, -0.04464164])

# %%
df.isna().sum()
# Out:
# age       0
# sex       0
# bmi       0
# bp        0
# s1        0
# s2        0
# s3        0
# s4        0
# s5        0
# s6        0
# target    0
# dtype: int64

# %%
fig = px.box(df, y=['bmi', 'age', 'bp', 's1', 's2', 's3', 's4', 's5', 's6'], title="Box Plot of Diabetes Features")
fig.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
correlation_matrix = df.corr()
df.corr()
# Out:
#              age       sex       bmi  ...        s5        s6    target
# age     1.000000  0.173737  0.185085  ...  0.270774  0.301731  0.187889
# sex     0.173737  1.000000  0.088161  ...  0.149916  0.208133  0.043062
# bmi     0.185085  0.088161  1.000000  ...  0.446157  0.388680  0.586450
# bp      0.335428  0.241010  0.395411  ...  0.393480  0.390430  0.441482
# s1      0.260061  0.035277  0.249777  ...  0.515503  0.325717  0.212022
# s2      0.219243  0.142637  0.261170  ...  0.318357  0.290600  0.174054
# s3     -0.075181 -0.379090 -0.366811  ... -0.398577 -0.273697 -0.394789
# s4      0.203841  0.332115  0.413807  ...  0.617859  0.417212  0.430453
# s5      0.270774  0.149916  0.446157  ...  1.000000  0.464669  0.565883
# s6      0.301731  0.208133  0.388680  ...  0.464669  1.000000  0.382483
# target  0.187889  0.043062  0.586450  ...  0.565883  0.382483  1.000000
#
# [11 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

df.head()
# Out:
#         age       sex       bmi        bp  ...        s4        s5        s6  target
# 0  0.038076  0.050680  0.061696  0.021872  ... -0.002592  0.019907 -0.017646   151.0
# 1 -0.001882 -0.044642 -0.051474 -0.026328  ... -0.039493 -0.068332 -0.092204    75.0
# 2  0.085299  0.050680  0.044451 -0.005670  ... -0.002592  0.002861 -0.025930   141.0
# 3 -0.089063 -0.044642 -0.011595 -0.036656  ...  0.034309  0.022688 -0.009362   206.0
# 4  0.005383 -0.044642 -0.036385  0.021872  ... -0.002592 -0.031988 -0.046641   135.0
#
# [5 rows x 11 columns]

# %%
target_scaler = StandardScaler()
df['target'] = target_scaler.fit_transform(df[['target']])
df.head()
# Out:
#         age       sex       bmi  ...        s5        s6    target
# 0  0.038076  0.050680  0.061696  ...  0.019907 -0.017646 -0.014719
# 1 -0.001882 -0.044642 -0.051474  ... -0.068332 -0.092204 -1.001659
# 2  0.085299  0.050680  0.044451  ...  0.002861 -0.025930 -0.144580
# 3 -0.089063 -0.044642 -0.011595  ...  0.022688 -0.009362  0.699513
# 4  0.005383 -0.044642 -0.036385  ... -0.031988 -0.046641 -0.222496
#
# [5 rows x 11 columns]

# %%
x = df.drop('target', axis=1)
y = df['target']

# %%
df.shape
# Out:
# (442, 11)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

model = MLPRegressor(hidden_layer_sizes=(80, 17, 7), max_iter=700, random_state=42, solver='adam', learning_rate_init=0.001, batch_size=50, early_stopping=True, validation_fraction=0.1, verbose=True,
activation='relu')

model.fit(x_train, y_train)
# Out:
# Iteration 1, loss = 0.50884714
# Validation score: -0.087367
# Iteration 2, loss = 0.49947688
# Validation score: -0.058026
# Iteration 3, loss = 0.49467982
# Validation score: -0.039997
# Iteration 4, loss = 0.49015627
# Validation score: -0.014989
# Iteration 5, loss = 0.48571513
# Validation score: 0.000434
# Iteration 6, loss = 0.47975117
# Validation score: 0.010238
# Iteration 7, loss = 0.47289515
# Validation score: 0.027334
# Iteration 8, loss = 0.46464860
# Validation score: 0.051731
# Iteration 9, loss = 0.45562977
# Validation score: 0.076454
# Iteration 10, loss = 0.44493346
# Validation score: 0.099442
# Iteration 11, loss = 0.43270787
# Validation score: 0.123710
# Iteration 12, loss = 0.41965340
# Validation score: 0.159761
# Iteration 13, loss = 0.40545539
# Validation score: 0.212565
# Iteration 14, loss = 0.39051873
# Validation score: 0.253978
# Iteration 15, loss = 0.37633234
# Validation score: 0.300446
# Iteration 16, loss = 0.36208079
# ...

# %%
loss_curve = model.loss_curve_
plt.plot(loss_curve)

# %% [markdown]
# EVALUATION

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([-0.09938586,  0.44361609, -0.02154722,  1.53196695, -0.39938217,
#        -0.729305  ,  1.32125865,  0.61054148, -0.77949845, -0.54826924,
#        -0.69597132,  0.17977625, -0.921742  ,  0.8711015 , -0.60879795,
#        -0.23070919,  1.07867608,  1.27156222,  0.63374448,  0.87996647,
#         0.80009939, -0.79171043, -0.88436922,  0.59865662,  0.08107062,
#         0.18879086,  0.51951208,  0.36886998, -1.00540313, -0.48574503,
#         0.36736011, -0.7251599 , -0.22968874,  0.48064773,  0.33328537,
#         0.57204037, -0.31222247, -0.3784497 ,  0.07431161, -0.97427253,
#        -0.85608843, -0.54161336,  0.16200987,  0.07831113,  0.47569714,
#        -0.95152962, -0.81280993, -0.54032216, -0.97233323,  0.12449382,
#         0.06492283, -0.91941898, -0.59530115, -0.5274189 ,  0.20381913,
#         0.05648656, -0.70627852,  0.77844041, -0.43172132, -0.89997637,
#         0.44557813,  0.7000502 , -0.17435427, -0.55397218, -0.28081153,
# ...

# %%
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
r2 = r2_score(y_test, y_pred)
print(f"R-squared: {r2}")
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error: {mae}")

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Mean Squared Error: 0.4574733412080716
# R-squared: 0.4879791320570602
# Mean Absolute Error: 0.5396882800182351
# Root Mean Squared Error: 0.6763677558902934

# %% [markdown]
# # BASELINE ERROR

# %%
y_pred = df['target'].sample(y_test.shape[0])

mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
r2 = r2_score(y_test, y_pred)
print(f"R-squared: {r2}")
mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error: {mae}")

rmse = np.sqrt(mse)
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Mean Squared Error: 1.9217361475668437
# R-squared: -1.1508772678121155
# Mean Absolute Error: 1.123365756682404
# Root Mean Squared Error: 1.3862669827875307
