# %%
a = 5
a
# Out:
# 5

# %%
c = a
c
# Out:
# 5

# %%
c = 15
c
# Out:
# 15

# %%
a
# Out:
# 5

# %%
a = [1, 2, 3]
a
# Out:
# [1, 2, 3]

# %%
c = a
c
# Out:
# [1, 2, 3]

# %%
c.append(4)
c
# Out:
# [1, 2, 3, 4]

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
a = [1, 2, 3]
c = a.copy()
c.append(4)
a
# Out:
# [1, 2, 3]

# %%
# deep copy
import copy
a = [1, [2, 3], 4]
c = copy.deepcopy(a)
c.append(4)
a
